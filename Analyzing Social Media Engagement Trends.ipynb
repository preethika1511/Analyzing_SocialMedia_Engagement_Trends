# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Preethi\Downloads\archive\social_media_engagement.csv") #https://www.kaggle.com/datasets/ashaychoudhary/the-power-of-social-media-engagement
df
# Out:
#      post_id   platform post_type         post_time  \
# 0          1   Facebook     image  2023-08-17 14:45
# 1          2   Facebook  carousel  2023-05-14 00:45
# 2          3  Instagram      poll  2023-02-21 16:15
# 3          4    Twitter     image  2023-11-16 00:45
# 4          5    Twitter     video  2023-05-23 00:30
# ..       ...        ...       ...               ...
# 995      996  Instagram     video  2023-04-25 07:15
# 996      997    Twitter     image  2023-09-09 07:30
# 997      998  Instagram     video  2023-08-18 23:15
# 998      999   Facebook      text  2023-10-05 00:15
# 999     1000    Twitter      poll  2023-09-11 21:15
#
#                          caption                          hashtags  likes  \
# 0               Best day ever! 🎉                           #Social   2121
# 1         Here's a quick update.      #Family, #Community, #Events   3660
# 2             Not my best day. 😞    #Beauty, #Fashion, #InstaDaily   4955
# ...

# %%
df.head(10) #top 10 rows
# Out:
#    post_id   platform post_type         post_time  \
# 0        1   Facebook     image  2023-08-17 14:45
# 1        2   Facebook  carousel  2023-05-14 00:45
# 2        3  Instagram      poll  2023-02-21 16:15
# 3        4    Twitter     image  2023-11-16 00:45
# 4        5    Twitter     video  2023-05-23 00:30
# 5        6  Instagram  carousel  2023-05-05 20:00
# 6        7  Instagram     image  2023-02-26 11:45
# 7        8  Instagram      text  2023-10-28 19:30
# 8        9   Facebook     video  2023-05-02 06:15
# 9       10    Twitter  carousel  2023-05-11 11:00
#
#                        caption                          hashtags  likes  \
# 0             Best day ever! 🎉                           #Social   2121
# 1       Here's a quick update.      #Family, #Community, #Events   3660
# 2           Not my best day. 😞    #Beauty, #Fashion, #InstaDaily   4955
# 3  Disappointed but moving on.  #Trending, #Tech, #Entertainment   1183
# ...

# %%
df.tail(10) #last 10 rows
# Out:
#      post_id   platform post_type         post_time  \
# 990      991    Twitter  carousel  2023-10-30 05:45
# 991      992    Twitter     image  2023-08-24 07:00
# 992      993   Facebook      poll  2023-09-29 16:45
# 993      994  Instagram      text  2023-09-28 03:45
# 994      995   Facebook  carousel  2023-11-11 17:15
# 995      996  Instagram     video  2023-04-25 07:15
# 996      997    Twitter     image  2023-09-09 07:30
# 997      998  Instagram     video  2023-08-18 23:15
# 998      999   Facebook      text  2023-10-05 00:15
# 999     1000    Twitter      poll  2023-09-11 21:15
#
#                          caption                        hashtags  likes  \
# 990  Disappointed but moving on.                   #Memes, #Tech   2857
# 991          Feeling down today.                           #Tech    103
# 992           Not my best day. 😞            #Friends, #Marketing   2899
# 993      Loving this new vibe! 😍                         #Foodie   1696
# ...

# %%
df.dtypes #datatype of each column
# Out:
# post_id             int64
# platform           object
# post_type          object
# post_time          object
# caption            object
# hashtags           object
# likes               int64
# comments            int64
# shares              int64
# caption_length      int64
# num_hashtags        int64
# post_hour           int64
# post_day           object
# sentiment_score    object
# dtype: object

# %%
df.isnull().sum() #checking null values
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# caption            0
# hashtags           0
# likes              0
# comments           0
# shares             0
# caption_length     0
# num_hashtags       0
# post_hour          0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
len(df.columns) #Number of columns
# Out:
# 14

# %%
len(df.index) #number of rows
# Out:
# 1000

# %%
df.loc[np.where(df['shares']==df["shares"].max())]  #details of the post with highest shares
# Out:
#      post_id  platform post_type         post_time                  caption  \
# 400      401  Facebook      text  2023-10-23 20:45  New post, check it out!
#
#     hashtags  likes  comments  shares  caption_length  num_hashtags  \
# 400  #Family   2948       309    1000              23             1
#
#      post_hour post_day sentiment_score
# 400         20   Monday         neutral

# %%
df.loc[np.where(df['likes']==df['likes'].min())]['platform'] #platform of the post with minimum likes
# Out:
# 829    Twitter
# Name: platform, dtype: object

# %%
df['post_hour'].mean() #Average post hour
# Out:
# 11.048

# %%
insta=df.loc[np.where(df['platform']=='Instagram')] #details of the post posted on instagram that has received negative sentiment score
insta.iloc[np.where(insta["sentiment_score"]=='negative')]
# Out:
#      post_id   platform post_type         post_time  \
# 2          3  Instagram      poll  2023-02-21 16:15
# 34        35  Instagram     image  2023-06-06 19:30
# 39        40  Instagram  carousel  2023-08-04 12:45
# 41        42  Instagram     video  2023-11-23 02:00
# 43        44  Instagram      text  2023-07-06 08:00
# ..       ...        ...       ...               ...
# 971      972  Instagram  carousel  2023-06-04 06:15
# 979      980  Instagram     video  2023-08-22 13:45
# 985      986  Instagram      poll  2023-04-05 23:15
# 995      996  Instagram     video  2023-04-25 07:15
# 997      998  Instagram     video  2023-08-18 23:15
#
#                          caption                        hashtags  likes  \
# 2             Not my best day. 😞  #Beauty, #Fashion, #InstaDaily   4955
# 34           Feeling down today.        #Fitness, #Foodie, #Tech   1309
# 39              Could be better.                         #Foodie    447
# ...

# %%
date_time=df['post_time'].str.split(" ",expand=True) #splitting post_time columns into two separate columns as Date and Time
date_time.columns=['Date','Time']
date_time
# Out:
#            Date   Time
# 0    2023-08-17  14:45
# 1    2023-05-14  00:45
# 2    2023-02-21  16:15
# 3    2023-11-16  00:45
# 4    2023-05-23  00:30
# ..          ...    ...
# 995  2023-04-25  07:15
# 996  2023-09-09  07:30
# 997  2023-08-18  23:15
# 998  2023-10-05  00:15
# 999  2023-09-11  21:15
#
# [1000 rows x 2 columns]

# %%
df['Date']=date_time['Date'] #adding date and time column in the dataset
df['Time']=date_time['Time']
df
# Out:
#      post_id   platform post_type         post_time  \
# 0          1   Facebook     image  2023-08-17 14:45
# 1          2   Facebook  carousel  2023-05-14 00:45
# 2          3  Instagram      poll  2023-02-21 16:15
# 3          4    Twitter     image  2023-11-16 00:45
# 4          5    Twitter     video  2023-05-23 00:30
# ..       ...        ...       ...               ...
# 995      996  Instagram     video  2023-04-25 07:15
# 996      997    Twitter     image  2023-09-09 07:30
# 997      998  Instagram     video  2023-08-18 23:15
# 998      999   Facebook      text  2023-10-05 00:15
# 999     1000    Twitter      poll  2023-09-11 21:15
#
#                          caption                          hashtags  likes  \
# 0               Best day ever! 🎉                           #Social   2121
# 1         Here's a quick update.      #Family, #Community, #Events   3660
# 2             Not my best day. 😞    #Beauty, #Fashion, #InstaDaily   4955
# ...

# %%
df.drop('post_time',inplace=True,axis=1) #removing post_time column
df
# Out:
#      post_id   platform post_type                      caption  \
# 0          1   Facebook     image             Best day ever! 🎉
# 1          2   Facebook  carousel       Here's a quick update.
# 2          3  Instagram      poll           Not my best day. 😞
# 3          4    Twitter     image  Disappointed but moving on.
# 4          5    Twitter     video             Exciting news! 🚀
# ..       ...        ...       ...                          ...
# 995      996  Instagram     video           Not my best day. 😞
# 996      997    Twitter     image             Could be better.
# 997      998  Instagram     video          Feeling down today.
# 998      999   Facebook      text             Best day ever! 🎉
# 999     1000    Twitter      poll       Here's a quick update.
#
#                              hashtags  likes  comments  shares  \
# 0                             #Social   2121       474     628
# 1        #Family, #Community, #Events   3660       432     694
# ...

# %%
len(df[df['sentiment_score']=='neutral']) #number of neutral sentiment score
# Out:
# 336

# %%
Sunday_posts=df[df["post_day"]=='Sunday'] #caption of posts posted on Sunday
Sunday_posts['caption']
# Out:
# 1           Here's a quick update.
# 6          Loving this new vibe! 😍
# 17         New post, check it out!
# 23                Exciting news! 🚀
# 30     Disappointed but moving on.
#                   ...
# 954              Just another day.
# 959        Loving this new vibe! 😍
# 968        Loving this new vibe! 😍
# 971            Feeling down today.
# 972               Best day ever! 🎉
# Name: caption, Length: 123, dtype: object

# %%
max_likes=df[df['likes']==df['likes'].max()]  #first 5 hashtags of the post that received max likes
max_likes['hashtags'].head()
# Out:
# 23          #Foodie, #InstaDaily
# 35    #Social, #Events, #Friends
# 38                       #Social
# 47                       #Family
# 73                #Tech, #Travel
# Name: hashtags, dtype: object

# %%
df[df['hashtags']=="#Tech, #Sports, #Entertainment"]  #find the details of the post that has hashtag as #Tech, #Sports, #Entertainment
# Out:
#      post_id platform post_type           caption  \
# 996      997  Twitter     image  Could be better.
#
#                            hashtags  likes  comments  shares  caption_length  \
# 996  #Tech, #Sports, #Entertainment    880        90      45              16
#
#      num_hashtags  post_hour  post_day sentiment_score        Date   Time
# 996             3          7  Saturday        negative  2023-09-09  07:30

# %%
len(df[df['caption_length'].between(25,30)])#number of posts that has caption length between 25 and 30
# Out:
# 81

# %%
df[(df['comments']>470) & (df['shares']>900)] #posts that has more than 470 comments and more than 900 shares
# Out:
#      post_id   platform post_type                  caption  \
# 159      160   Facebook     video      Feeling down today.
# 526      527  Instagram     video         Best day ever! 🎉
# 566      567   Facebook     image  New post, check it out!
# 593      594   Facebook  carousel         Exciting news! 🚀
# 604      605   Facebook     video  New post, check it out!
# 673      674  Instagram     video  New post, check it out!
# 721      722  Instagram     image         Exciting news! 🚀
# 830      831  Instagram  carousel        Just another day.
# 840      841  Instagram  carousel  Loving this new vibe! 😍
#
#                                 hashtags  likes  comments  shares  \
# 159                           #Marketing   5000       500     923
# 526         #Photography, #Travel, #Tech   2016       500     974
# 566        #Community, #Family, #Friends   1852       500     939
# 593        #Events, #Friends, #Marketing   4168       500     999
# ...

# %%
df[df["post_hour"]<14] #details of posts posted before 4PM (i.e) 14:00
# Out:
#      post_id   platform post_type                      caption  \
# 1          2   Facebook  carousel       Here's a quick update.
# 3          4    Twitter     image  Disappointed but moving on.
# 4          5    Twitter     video             Exciting news! 🚀
# 6          7  Instagram     image      Loving this new vibe! 😍
# 8          9   Facebook     video            Just another day.
# ..       ...        ...       ...                          ...
# 991      992    Twitter     image          Feeling down today.
# 993      994  Instagram      text      Loving this new vibe! 😍
# 995      996  Instagram     video           Not my best day. 😞
# 996      997    Twitter     image             Could be better.
# 998      999   Facebook      text             Best day ever! 🎉
#
#                              hashtags  likes  comments  shares  \
# 1        #Family, #Community, #Events   3660       432     694
# 3    #Trending, #Tech, #Entertainment   1183        90     187
# ...

# %%
#dataset between the dates 2023-10-15 and 2023-11-15
df['Date'] = pd.to_datetime(df['Date']) #ensuring the date column is in datetime format
start_date="2023-10-15"
end_date="2023-11-15"
df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
# Out:
#      post_id   platform post_type                      caption  \
# 7          8  Instagram      text      New post, check it out!
# 12        13   Facebook  carousel           Not my best day. 😞
# 52        53    Twitter     video             Exciting news! 🚀
# 96        97    Twitter     video       Here's a quick update.
# 100      101   Facebook     image            Just another day.
# ..       ...        ...       ...                          ...
# 964      965    Twitter      text        Amazing experience! 🌟
# 966      967    Twitter  carousel            Just another day.
# 977      978    Twitter  carousel        Amazing experience! 🌟
# 990      991    Twitter  carousel  Disappointed but moving on.
# 994      995   Facebook  carousel            Just another day.
#
#                           hashtags  likes  comments  shares  caption_length  \
# 7                         #Fashion   1274        45     216              23
# ...

# %%
df[df['Date']>'2023-12-30']['platform'] #platforms of the post posted after 2024-12-30
# Out:
# 60     Instagram
# 364      Twitter
# 819     Facebook
# Name: platform, dtype: object

# %%
df.value_counts('hashtags') #count of each hashtag
# Out:
# hashtags
# #Tech                            34
# #Memes                           23
# #Beauty                          22
# #Foodie                          20
# #Marketing                       19
#                                  ..
# #Friends, #Events, #Family        1
# #Foodie, #Travel, #Tech           1
# #Foodie, #Travel, #InstaDaily     1
# #Foodie, #Travel, #Beauty         1
# #Trending, #Tech, #Sports         1
# Name: count, Length: 400, dtype: int64

# %%
negative_score=df[df['sentiment_score']=='negative']
df1=negative_score.head(7)
df1['caption'].apply(lambda x: x+" #All is well") #add '#All is well' in top 7 captions with negative sentiment score
# Out:
# 2              Not my best day. 😞 #All is well
# 3     Disappointed but moving on. #All is well
# 10            Feeling down today. #All is well
# 12             Not my best day. 😞 #All is well
# 25    Disappointed but moving on. #All is well
# 28               Could be better. #All is well
# 30    Disappointed but moving on. #All is well
# Name: caption, dtype: object

# %%
df2=df[df["platform"]!='Twitter'] #remove all the details of the post posted on Twitter and delete of all columns except caption ,post_type and hashtags
df2.drop(['post_id','platform','likes','comments','shares','caption_length','num_hashtags','post_hour','post_day','sentiment_score','Date','Time'],axis=1)
# Out:
#     post_type                  caption                        hashtags
# 0       image         Best day ever! 🎉                         #Social
# 1    carousel   Here's a quick update.    #Family, #Community, #Events
# 2        poll       Not my best day. 😞  #Beauty, #Fashion, #InstaDaily
# 5    carousel  New post, check it out!                    #Photography
# 6       image  Loving this new vibe! 😍                         #Foodie
# ..        ...                      ...                             ...
# 993      text  Loving this new vibe! 😍                         #Foodie
# 994  carousel        Just another day.               #Friends, #Family
# 995     video       Not my best day. 😞         #Beauty, #Travel, #Tech
# 997     video      Feeling down today.                    #Photography
# 998      text         Best day ever! 🎉                        #Friends
#
# [672 rows x 3 columns]

# %%
df2=df[df["platform"]!='Twitter'] #remove all the details of the post posted on Twitter and delete of all columns except caption ,post_type and hashtags
df3=df2.drop([col for col in df2.columns if col not in ['caption','post_type','hashtags']],axis=1)
df3
# Out:
#     post_type                  caption                        hashtags
# 0       image         Best day ever! 🎉                         #Social
# 1    carousel   Here's a quick update.    #Family, #Community, #Events
# 2        poll       Not my best day. 😞  #Beauty, #Fashion, #InstaDaily
# 5    carousel  New post, check it out!                    #Photography
# 6       image  Loving this new vibe! 😍                         #Foodie
# ..        ...                      ...                             ...
# 993      text  Loving this new vibe! 😍                         #Foodie
# 994  carousel        Just another day.               #Friends, #Family
# 995     video       Not my best day. 😞         #Beauty, #Travel, #Tech
# 997     video      Feeling down today.                    #Photography
# 998      text         Best day ever! 🎉                        #Friends
#
# [672 rows x 3 columns]
